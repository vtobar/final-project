# %%
# %matplotlib inline

import pandas as pd

# these will be useful later
import numpy  as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
age_group = pd.read_csv('SUICIDE.csv')
age_group.columns
# Out:
# Index(['Year', 'Category', 'Code', 'Value', 'Suicide Deaths', 'Population',
#        'Rate Per 100,000'],
#       dtype='object')

# %%
age_group['Value'] = age_group['Category Value']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Category Value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-397affceb608> in <module>()
# ----> 1 age_group['Value'] = age_group['Category Value']
#
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/Vane/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Category Value'

# %%
pretable = age_group[age_group['Category'] == 'Age_Group']
table = pretable[pretable['Value'] != 'Total']

# %%
age_group_2003 = table[table["Year"] == 2003]
age_group_2003_graph= age_group_2003.sort_values(by= "Suicide Deaths", ascending = False)
age_group_2003_graph
# Out:
#      Year   Category  Code  Value  Suicide Deaths  Population  \
# 55   2003  Age_Group     5  35-44             237     3038513
# 66   2003  Age_Group     6  45-54             234     2715954
# 44   2003  Age_Group     4  25-34             175     2670831
# 77   2003  Age_Group     7  55-64             173     1916166
# 33   2003  Age_Group     3  20-24             100     1313322
# 88   2003  Age_Group     8  65-74              96     1249837
# 99   2003  Age_Group     9  75-84              90      895796
# 22   2003  Age_Group     2  10-19              62     2606471
# 110  2003  Age_Group    10    85+              39      343326
# 11   2003  Age_Group     1  00-09               0     2439899
#
#      Rate Per 100,000
# 55                7.8
# 66                8.6
# 44                6.6
# 77                9.0
# 33                7.6
# 88                7.7
# 99               10.0
# 22                2.4
# 110              11.4
# 11                0.0

# %%
age_group_2003 = table[table["Year"] == 2003]
age_group_2003_graph= age_group_2003.sort_values(by= "Suicide Deaths", ascending = False)

sns.set(style="ticks")

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

x = age_group_2003_graph["Value"]
y = age_group_2003_graph["Suicide Deaths"]

# This Function takes as input a custom palette
g = sns.barplot(x, y, palette=sns.color_palette(flatui))

# remove the top and right line in graph
sns.despine()

# Set the size of the graph from here
g.figure.set_size_inches(12,7)
# Set the Title of the graph from here
g.axes.set_title('Number of Suicides by Age Group in 2003',
    fontsize=34,color="b",alpha=0.3)
# Set the xlabel of the graph from here
g.set_xlabel("Age Group",size = 26,color="b",alpha=0.50)
# Set the ylabel of the graph from here
g.set_ylabel("Number of Suicides",size = 26,color="b",alpha=0.5)
# Set the ticklabel size and color of the graph from here
g.tick_params(labelsize=12,labelcolor="black")

# %%
age_group_2004 = table[table["Year"] == 2004]
age_group_2004_graph= age_group_2004.sort_values(by= "Suicide Deaths", ascending = False)

sns.set(style="ticks")

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

x = age_group_2004_graph["Value"]
y = age_group_2004_graph["Suicide Deaths"]

# This Function takes as input a custom palette
g = sns.barplot(x, y, palette=sns.color_palette(flatui))

# remove the top and right line in graph
sns.despine()

# Set the size of the graph from here
g.figure.set_size_inches(12,7)
# Set the Title of the graph from here
g.axes.set_title('Number of Suicides by Age Group in 2004',
    fontsize=34,color="b",alpha=0.3)
# Set the xlabel of the graph from here
g.set_xlabel("Age Group",size = 26,color="b",alpha=0.50)
# Set the ylabel of the graph from here
g.set_ylabel("Number of Suicides",size = 26,color="b",alpha=0.5)
# Set the ticklabel size and color of the graph from here
g.tick_params(labelsize=12,labelcolor="black")

# %%
#2005

age_group_2005 = table[table["Year"] == 2005]
age_group_2005_graph= age_group_2005.sort_values(by= "Suicide Deaths", ascending = False)

sns.set(style="ticks")

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

x = age_group_2005_graph["Value"]
y = age_group_2005_graph["Suicide Deaths"]

# This Function takes as input a custom palette
g = sns.barplot(x, y, palette=sns.color_palette(flatui))

# remove the top and right line in graph
sns.despine()

# Set the size of the graph from here
g.figure.set_size_inches(12,7)
# Set the Title of the graph from here
g.axes.set_title('Number of Suicides by Age Group in 2005',
    fontsize=34,color="b",alpha=0.3)
# Set the xlabel of the graph from here
g.set_xlabel("Age Group",size = 26,color="b",alpha=0.50)
# Set the ylabel of the graph from here
g.set_ylabel("Number of Suicides",size = 26,color="b",alpha=0.5)
# Set the ticklabel size and color of the graph from here
g.tick_params(labelsize=12,labelcolor="black")

# %%
#2013

age_group_2013 = table[table["Year"] == 2013]
age_group_2013_graph= age_group_2013.sort_values(by= "Suicide Deaths", ascending = False)

sns.set(style="ticks")

flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

x = age_group_2013_graph["Value"]
y = age_group_2013_graph["Suicide Deaths"]

# This Function takes as input a custom palette
g = sns.barplot(x, y, palette=sns.color_palette(flatui))

# remove the top and right line in graph
sns.despine()

# Set the size of the graph from here
g.figure.set_size_inches(12,7)
# Set the Title of the graph from here
g.axes.set_title('Number of Suicides by Age Group in 2013',
    fontsize=34,color="b",alpha=0.3)
# Set the xlabel of the graph from here
g.set_xlabel("Age Group",size = 26,color="b",alpha=0.50)
# Set the ylabel of the graph from here
g.set_ylabel("Number of Suicides",size = 26,color="b",alpha=0.5)
# Set the ticklabel size and color of the graph from here
g.tick_params(labelsize=12,labelcolor="black")
